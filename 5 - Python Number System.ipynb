# %% [markdown]
# # 16th -- Number System

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
bin(256)
# Out:
# '0b100000000'

# %%
bin(1028)
# Out:
# '0b10000000100'

# %%
int(0b11110)
# Out:
# 30

# %%
int (0b10000000100)
# Out:
# 1028

# %%
oct (25)
# Out:
# '0o31'

# %%
oct(200)
# Out:
# '0o310'

# %%
int(0o31)
# Out:
# 25

# %%
int(0o310)
# Out:
# 200

# %%
print(0xa)
print(0xb)
print(0xc)
print(0xd)
print(0xe)
print(0xf)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
print(0xg)
# Out:
#   Cell In[32], line 1
#     print(0xg)
#            ^
# SyntaxError: invalid hexadecimal literal

# %% [markdown]
# # Bitwise operator
#  - Complement--  ~
#  - Bitwise And--  &
#  - Bitwise Or--   |
#  - Xor--  ^
#  - Left shift-- <<
#  - Right shift -- >>

# %% [markdown]
# # Complemnt -- ~

# %%
a = 3

# %%
-a
# Out:
# -3

# %%
~3
# Out:
# -4

# %%
~a
# Out:
# -4

# %%
16
# Out:
# 16

# %%
~16
# Out:
# -17

# %%
~555
# Out:
# -556

# %% [markdown]
# # Bitwise And , Or

# %%
12 & 13
# Out:
# 12

# %%
print (bin(12))
print (bin(13))
# Out:
# 0b1100
# 0b1101

# %%
12 & 20
# Out:
# 4

# %%
print (bin(12))
print (bin(20))
# Out:
# 0b1100
# 0b10100

# %%
12 | 13
# Out:
# 13

# %%
print (bin(12))
print (bin(13))
# Out:
# 0b1100
# 0b1101

# %% [markdown]
# # Xor ^
#
# ![1_fKQUHeIbZpMiBW8XC3M70A.png](attachment:0114735a-753c-4a29-9380-ac2920cbc943.png)

# %%
12 ^ 13
# Out:
# 1

# %%
print (bin(12))
print (bin(13))
# Out:
# 0b1100
# 0b1101

# %%
25 ^ 30
# Out:
# 7

# %%
print (bin(25))
print (bin(30))
# Out:
# 0b11001
# 0b11110

# %% [markdown]
# # Left shift  (we gain the bit (0s we will gain))

# %%
 21 << 1
# Out:
# 42

# %%
12 << 1
# Out:
# 24

# %%
12 << 2
# Out:
# 48

# %%
24 << 3
# Out:
# 192

# %%
bin (24)
# Out:
# '0b11000'

# %%
25 << 1
# Out:
# 50

# %% [markdown]
# # Right shift >> ( We will loose the bits)

# %%
12>>1
# Out:
# 6

# %%
13 >> 2
# Out:
# 3

# %%
25 >> 2
# Out:
# 6

# %% [markdown]
# # Print()

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %% [markdown]
# # Print Format method ( .format )
# - first deside how the print statement should be
# - like:- The addition of 20 and 30 is = 50
# - then replace the variable position with curly brtacesm { }
# - then appply .format(val1,val2,....val-n methodm

# %%
num1 = 30 
num2 = 40
add = num1 + num2
print ('The addition of {} and {} is = {}' .format(num1,num2,add))
# Out:
# The addition of 30 and 40 is = 70

# %%
num1 = 30 
num2 = 40
sub = num1 - num2
print ('the sub of {} and {} is = {}' .format(num1,num2,sub))
# Out:
# the sub of 30 and 40 is = -10

# %% [markdown]
# # More short format method
# - variable should be in curly braces
# - and write everything inside quots ''
# - at starting simpaly add f

# %%
num4 = 15
num5 = 10
add = num4+num5
print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 30 and 40 is = 25

# %% [markdown]
# # print () with end statement.
# - Here we will use end statement that joint line from end of one string to starting of other
# string

# %%
print('hello') # 1st stmt
print('good evening') #2nd stmt
# Out:
# hello
# good evening

# %%
print('hello ' , end = '',) # 1st stmt
print('goodevening') #2nd stmt
# Out:
# hello goodevening

# %% [markdown]
# # Seprator
# - here one print statement only we use
# - insisde one print statement we have multipal values
# - we want to seperate these multipal values with anything

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hii ','bhai ','kese ho',sep = '')
# Out:
# hii bhai kese ho

# %%
print('kaisa kai ', ' paltan',sep = '#')
# Out:
# kaisa kai # paltan

# %%
print(5,'.,')
# Out:
# 5 .,

# %%
print(5,'.',sep = '')
# Out:
# 5.

# %%
print(1,2,end=' ' ,)
print(3,'.',sep='')
# Out:
# 1 2 3.
