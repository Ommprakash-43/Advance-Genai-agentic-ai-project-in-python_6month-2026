# %% [markdown]
# # 17th; import

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
math.sqrt(25)

# %%
round(math.sqrt(25))

# %%
x = round(math.sqrt(25))
x

# %%
math.floor(25.2)

# %%
math.ceil(25.2)

# %%
pow(5,2)

# %%
math.pi

# %%
pi = 1.75
pi
# Out:
# 1.75

# %%
# in python there is no constant value , only variables are there.

# %%
# help() -- you wanted to know any information python then use -- quit if

# %%
m.sqrt(36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m.sqrt(36)
#
# NameError: name 'm' is not defined

# %%
math.sqrt(36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 math.sqrt(36)
#
# NameError: name 'math' is not defined

# %%
import math as m

# %%
m.sqrt(36)
# Out:
# 6.0

# %%
round(m.sqrt(36))
# Out:
# 6

# %%
from math import sqrt, pow # math has many function if you want to import specific function then use import
print(pow(2,3))
print(m.sqrt(25))
# Out:
# 8.0
# 5.0

# %%
from math import * # it import's all the functions of math

# %%
print(math.e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(math.e)
#
# NameError: name 'math' is not defined

# %%
print(pow(2,8))
# Out:
# 256.0

# %% [markdown]
# # input()

# %%
input()
input()
# Out:
#  hi
#  heloo
# 'heloo'

# %%
x = input()
y = input()
z = x + y
print(z)
# Out:
#  12
#  45
# 1245

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = int(input())
y = int(input())
z = x + y
print(z)
# Out:
#  5
#  12
# 17

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1 = input('Enter 1st number')  #whenevery you works in input function it always give you string
y1 = input('Enter 2nd number')  #it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# Enter 1st number 12
# Enter 2nd number 10
# 1210

# %%
x1 = int(input('Enter 1st number'))  #whenevery you works in input function it always give you string
y1 = int(input('Enter 2nd number'))  #it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# Enter 1st number 15
# Enter 2nd number 10
# 25

# %%
x2 = input('Enter user_name: ') #whenevery you works in input function it always give you string 
y2 = input('Enter password: ') # it wont understand as arithmetic operator
z2 = x2 + y2
print(z2)
# Out:
# Enter user_name:  ommprakash
# Enter password:  10245
# ommprakash10245

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string good
# good

# %%
st = input('enter a string')[0]
print(st)
# Out:
# enter a string hello
# h

# %%
st = input('enter a string')[0:2]
print(st)
# Out:
# enter a string hello
# he

# %%
st = input('enter a string')[8:13]
print(st)
# Out:
# enter a string 493744861032
# 1032
