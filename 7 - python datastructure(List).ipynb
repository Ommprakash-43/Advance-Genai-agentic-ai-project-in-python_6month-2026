# %% [markdown]
# # LIST DATASTRUCTURE
# - List is an ordered sequence of items.
# -  We can have different data types under a list. E.g we can have integer, float and string items in
# a same list.

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.append(10)  # Append :Append object to the end of the list.

# %%
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [ 10, 2.3, 1+2j ,'nit' ,[1,2,3]]

# %%
l1
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 5

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 2004954879552
# 2004954927296

# %%
l.copy
# Out:
# <function list.copy()>

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2 = l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2004954879552
# 2004954927296
# 2004954823936

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
len(l2)
# Out:
# 6

# %%
l2.clear()

# %%
len(l2)
# Out:
# 0

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(20) # count :Return number of occurrences of value.
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l.count(200)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
a = [1,2,3]
b = [4,5,6]

a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l1)

# %%
l2
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]

# %%
l2.extend(l)

# %%
l2
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), 'nit', [1, 2, 3]]
# [10, 2.3, (1+2j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
job = [5000]
job
# Out:
# [5000]

# %%
job [0]
# Out:
# 5000

# %%
job[0] = 10000

# %%
job
# Out:
# [10000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[4]
# Out:
# 50

# %%
l[4] = 500

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
# list is mutable.

# %%
l.index(100)
# Out:
# 0

# %%
l2
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.index(10)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.insert(2, 25)  #Signature: l.insert(index, object, /)
l                  #Docstring: Insert object before index.
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500, 10]

# %%
l.pop() #Remove and return item at index (default last).
# Out:
# 10

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500]

# %%
l2
# Out:
# [10, 2.3, (1+2j), 'nit', [1, 2, 3], 10, 20, 30, 40, 50, 10]

# %%
l2.pop()
# Out:
# 10

# %%
l2.pop(2)  # pop() - remove the value by indexing wise if the argument is given
# Out:
# (1+2j)

# %%
l2
# Out:
# [10, 2.3, 'nit', [1, 2, 3], 10, 20, 30, 40, 50]

# %%
l2.remove(40) # remove the value by value wise

# %%
l2
# Out:
# [10, 2.3, 'nit', [1, 2, 3], 10, 20, 30, 50]

# %%
l
# Out:
# [100, 20, 25, 30, 40, 500]

# %%
l.reverse()

# %%
l
# Out:
# [500, 40, 30, 25, 20, 100]

# %%
# reverse is not sorting

# %%
l
# Out:
# [500, 40, 30, 25, 20, 100]

# %%
l.sort()

# %%
l
# Out:
# [20, 25, 30, 40, 100, 500]

# %%
l.sort(reverse = True)
l
# Out:
# [500, 100, 40, 30, 25, 20]

# %% [markdown]
# # List Practice

# %% [markdown]
# # List Creation

# %%
list = []

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
l1 = ['Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'} , 2.4]

# %%
l1
# Out:
# ['Asif', 25, [50, 100], [150, 90], {'David', 'John'}, 2.4]

# %%
# list have Int,str,nested list,float are possible.

# %%
len(l1)
# Out:
# 6

# %% [markdown]
# # List indexing
#
#
# ![Screenshot 2026-03-21 191631.png](attachment:587c19a5-8589-4fb6-a2a4-7d9fdc17e6e5.png)

# %%
l1[0]
# Out:
# 'Asif'

# %%
l1[0][1]
# Out:
# 's'

# %%
l1[2]
# Out:
# [50, 100]

# %%
l1[-2]
# Out:
# {'David', 'John'}

# %% [markdown]
# # List Slicing

# %%
l2 = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
l2
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l2[1:3]
# Out:
# ['two', 'three']

# %%
l2[2:5]
# Out:
# ['three', 'four', 'five']

# %%
l2[ :100]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l2[0: ]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l2[:2]
# Out:
# ['one', 'two']

# %%
l2[ :-3]
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# # Add , Remove & Change Items

# %%
l3 = [ 1,2,3,4,5,6,7,8]

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l3.append(10)

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10]

# %%
l3.insert(3,3.5)

# %%
l3
# Out:
# [1, 2, 3, 3.5, 4, 5, 6, 7, 8, 10]

# %%
l3.insert(6,5.9)

# %%
l3
# Out:
# [1, 2, 3, 3.5, 4, 5, 5.9, 6, 7, 8, 10]

# %%
l3.remove(3.5)
l3
# Out:
# [1, 2, 3, 4, 5, 5.9, 6, 7, 8, 10]

# %%
l3.remove(5.9)

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10]

# %%
l3.pop()
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l3.pop(0)
# Out:
# 1

# %%
l3
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
del l3[2]

# %%
l3
# Out:
# [2, 3, 5, 6, 7, 8]

# %%
l3 [0] = 0
l3 [1] = 1
l3 [2] = 2
l3
# Out:
# [0, 1, 2, 6, 7, 8]

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
del l3
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 del l3
# ----> 2 l3
#
# NameError: name 'l3' is not defined

# %% [markdown]
# # Copy List

# %%
l4 = [ 10,20,30,40,50,60 ]

# %%
l4
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l5 = l4

# %%
l5
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
id(l5) , id(l4)
# Out:
# (1817154751232, 1817154751232)

# %%
l6 = l4.copy()

# %%
l6
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
id(l6)
# Out:
# 1817154697536

# %%
l4[0] = 1
l4
# Out:
# [1, 20, 30, 40, 50, 60]

# %%
l6
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# # Reverse & Sort List

# %%
l6
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l6.reverse()

# %%
l6
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
l6 = l6[ : -1]

# %%
l6
# Out:
# [60, 50, 40, 30, 20]

# %%
l6 = l6[::-1]

# %%
l6
# Out:
# [20, 30, 40, 50, 60]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort() # Sort list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse = True) # Sort list in decending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98]
sorted(mylist4)
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]
