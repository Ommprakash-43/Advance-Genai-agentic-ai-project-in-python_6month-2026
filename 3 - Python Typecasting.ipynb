# %% [markdown]
# # Python Typecasting
# - car() - cars function with 0 arguments
# - asian_cars('tata' , 'mahindra') -- asian cars function with 2 arguments
# - german_cars('audi' , 'bmw' , 'ferrari' ) -- german cars function with 3 arguments
# - in this i define 3 functions ,, function ends with ()

# %% [markdown]
# # Typecasing another datatypes to integer

# %%
int(2.3)
# Out:
# 2

# %%
int (2.3 , 3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 int (2.3 , 3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int (True)
# Out:
# 1

# %%
int (1+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int (1+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int(10)
# Out:
# 10

# %%
int ('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int ('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatype to Float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(2+6j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 float(2+6j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(25)
# Out:
# 25.0

# %%
float('hii')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float('hii')
#
# ValueError: could not convert string to float: 'hii'

# %% [markdown]
# # all other datatype to Boolean

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool ('hii')
# Out:
# True

# %%
bool(2+4j)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool ('zero')
# Out:
# True

# %%
bool(1.2)
# Out:
# True

# %%
val2 =[92]
import sys
sys.getsizeof(val2)
# Out:
# 64

# %%
import sys
val1 = [10]
sys.getsizeof(val1)
# Out:
# 64

# %%
val1 = 10 # Integer data type
print(val1)
print(type(val1)) # type of object
print(sys.getsizeof(val1)) # size of integer object in bytes
print(val1, " is Integer?", isinstance(val1, int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78 # Float data type
print(val2)
print(type(val2)) # type of object
print(sys.getsizeof(val2)) # size of float object in bytes
print(val2, " is float?", isinstance(val2, float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j # Complex data type
print(val3)
print(type(val3)) # type of object
print(sys.getsizeof(val3)) # size of float object in bytes
print(val3, " is complex?", isinstance(val3, complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28
