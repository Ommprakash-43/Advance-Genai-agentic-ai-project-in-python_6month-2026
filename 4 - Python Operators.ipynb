# %% [markdown]
# # Python operators
#  - Arithmatic Operator
#  - Assignment Operator
#  - Relational Operator
#  - Logical Operator
#  - Unary Operator
#
# ![Screenshot 2026-03-13 202555.png](attachment:d5195db5-3386-4b73-8ec6-28de14bf34fb.png)

# %% [markdown]
# # Arithmetic Operator -  + , - ,* , / , // , **
#
# ![1_XRz6kN1VX6S1qRCr4GlUgw.png](attachment:a7c166e7-d498-4406-9432-32a1a46f239c.png)

# %%
x1 , y1 = 10,5

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1**y1
# Out:
# 100000

# %% [markdown]
# # Assignment Operator - = , += , -= , *= , /=

# %%
x = 2

# %%
x = x + 5

# %%
x
# Out:
# 7

# %%
x += 2
x
# Out:
# 9

# %%
x -= 3
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x /= 2
x
# Out:
# 6.0

# %%
x //= 2
x
# Out:
# 3.0

# %%
a,b = 5,8
a
b
# Out:
# 8

# %%
a,b = 5,8
print(a)
print(b)
# Out:
# 5
# 8

# %%
a
# Out:
# 5

# %%
b
# Out:
# 8

# %% [markdown]
# # Unary Operator
# - unary means 1 | Binary Means 2
# - Here we are applying unary minus operator(-) on the operand n;

# %%
n = 4
n
# Out:
# 4

# %%
m = (-n)
m
# Out:
# -4

# %%
n
# Out:
# 4

# %%
-n
# Out:
# -4

# %% [markdown]
# # Relational Operator
#  - we are using this operator for comparing

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a = b

# %%
a
# Out:
# 6

# %%
b
# Out:
# 6

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
b = 8

# %%
a != b
# Out:
# True

# %% [markdown]
# # Logical Operator  -- and || or || not
#
#
# ![images.png](attachment:1e9a6ad4-eb7f-4955-9785-73bb2b0db1b4.png)
#
#
# ![Screenshot 2026-03-13 203012.png](attachment:bd62ffd9-5d16-4a24-a9d6-3c2723e8738e.png)

# %%
a = 5
b = 2

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a > 8 or b < 4
# Out:
# True

# %%
x = False 
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x = not x
x
# Out:
# False

# %%
not x
# Out:
# True
