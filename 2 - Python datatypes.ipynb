# %% [markdown]
# # -- Python Datatypes or Python Values

# %%
i = 23 # (i = variable & 23 = value)
i
# Out:
# 23

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140731148969576

# %%
f = 110.2
f
# Out:
# 110.2

# %%
type(f)
# Out:
# float

# %%
gold_price = 14800.58
gold_price
# Out:
# 14800.58

# %%
type(gold_price)
# Out:
# float

# %%
10+5
10-5
10*5
# Out:
# 50

# %%
print(10+5)
print(10-5)
print(10*5)
# Out:
# 15
# 5
# 50

# %%
f1 = 2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e3
f2
# Out:
# 3500.0

# %%
f3 = 3.2E3
f3
# Out:
# 3200.0

# %% [markdown]
# # Statement

# %%
p = 10
q = 10
r = q
p , type(p) , hex(id(q))
# Out:
# (10, int, '0x7ff85112a4c8')

# %%
r , type(r), hex(id(r))
# Out:
# (10, int, '0x7ff85112a4c8')

# %%
p = 20
p = p + 10 # Variable Overwriting
p
# Out:
# 30

# %% [markdown]
# # variable assignment

# %%
int = 10
float = 2.5
str = 'hii python '
print ( int)
print(float)
print (str)
# Out:
# 10
# 2.5
# hii python

# %%
intvar , floatvar , strvar = 10,2.57,"Python Language" # Using commas to separat
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44 # All variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# # Boolean value
#  True = 1
#  False = 0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # Complex

# %%
c = 10+20j # 10 - real part & 20 imaginary part where j = square root of -1
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 20.0

# %%
c.real
# Out:
# 10.0

# %% [markdown]
# # Integer , Float , Boolean , Complex

# %% [markdown]
# # 11th march " String "

# %%
Welcome to nareshid and follwo our youtube and instagram
# Out:
#   Cell In[1], line 1
#     Welcome to nareshid and follwo our youtube and instagram
#             ^
# SyntaxError: invalid syntax

# %%
'Welcome to nareshid and follwo our youtube and instagram'
# Out:
# 'Welcome to nareshid and follwo our youtube and instagram'

# %%
"Welcome to nareshid and follwo our youtube and instagram"
# Out:
# 'Welcome to nareshid and follwo our youtube and instagram'

# %%
'''Welcome to nareshid and follwo our youtube and instagram'''
# Out:
# 'Welcome to nareshid and follwo our youtube and instagram'

# %%
''''Welcome to nareshid and follwo our youtube and instagram''''
# Out:
#   Cell In[5], line 1
#     ''''Welcome to nareshid and follwo our youtube and instagram''''
#                                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'Welcome to nareshid 
and follwo our
youtube and instagram'
# Out:
#   Cell In[6], line 1
#     'Welcome to nareshid
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"Welcome to nareshid 
and follwo our
youtube and instagram"
# Out:
#   Cell In[7], line 1
#     "Welcome to nareshid
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''Welcome to nareshid 
 and follwo our
 youtube and instagram'''  #why \n is coming
# Out:
# 'Welcome to nareshid \n and follwo our\n youtube and instagram'

# %%
'Welcome to nareshid '
and follwo our
youtube and instagram
# Out:
#   Cell In[9], line 2
#     and follwo our
#     ^
# SyntaxError: invalid syntax

# %%
s = 'python'
s
# Out:
# 'python'

# %%
type(s)
# Out:
# str

# %%
s1 = 'welcome'
s1
# Out:
# 'welcome'

# %%
s1[2]
# Out:
# 'l'

# %%
s1[4]
# Out:
# 'o'

# %%
s1[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s1[8]
#
# IndexError: string index out of range

# %%
s1[-4]
# Out:
# 'c'

# %%
s1
# Out:
# 'welcome'

# %%
len(s1)
# Out:
# 7

# %%
s1[6]
# Out:
# 'e'

# %%
s1
# Out:
# 'welcome'

# %%
s1[:]
# Out:
# 'welcome'

# %%
s1[1:4] #forward slicing  , left side always (n-1)
# Out:
# 'elc'

# %%
s1[3:7]
# Out:
# 'come'

# %%
s2 = 'na,reshtechnology'
s2
# Out:
# 'na,reshtechnology'

# %%
s2[2]
# Out:
# ','

# %%
len(s2)
# Out:
# 17

# %%
s2[1:15]
# Out:
# 'a,reshtechnolo'

# %%
s2[1:900]
# Out:
# 'a,reshtechnology'

# %%
s3 = 'Nareshtechnology'
s3
# Out:
# 'Nareshtechnology'

# %%
s3 [0:]
# Out:
# 'Nareshtechnology'

# %%
s3[ :6]
# Out:
# 'Naresh'

# %%
s3 [ :20]
# Out:
# 'Nareshtechnology'

# %%
mystr = 'Hello World' # Define string using single quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = "Hello World" # Define string using double quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = '''hello 
                       World''' # Define string using triple quotes
print(mystr)
# Out:
# hello
#                        World

# %%
s6 = 'Ommprakash ''Odisha ''Bahdrak '
s6
# Out:
# 'Ommprakash Odisha Bahdrak '

# %%
s6 = 'Ommprakash '
'Odisha '
'Bahdrak '   # why it shows only ommprakash
s6
# Out:
# 'Ommprakash '

# %%
s6 = "Ommprakash" 
"Odisha" 
"Bahdrak "    # why it shows only ommprakash
s6
# Out:
# 'Ommprakash'

# %%
mystr = ('Happy '
'Monday '
'Everyone')
mystr
# Out:
# 'Happy Monday Everyone'

# %%
s7 = 'Wowoo '
s7 = s7*4
s7
# Out:
# 'Wowoo Wowoo Wowoo Wowoo '

# %%
len(s7)
# Out:
# 24

# %% [markdown]
# # Update & Delete String

# %%
str1 = 'hello python '
str1
# Out:
# 'hello python '

# %%
str1[0:5]
# Out:
# 'hello'

# %%
str1[0:5] = 'holaa'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 str1[0:5] = 'holaa'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # Delete a string
print(srt1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 del str1 # Delete a string
#       2 print(srt1)
#
# NameError: name 'str1' is not defined
